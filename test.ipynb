# %%
from playwright.sync_api import sync_playwright
import time

# %%
a = ['']
b = [1, 2]
c = [2, 4]

# %%
a = ['']*len(b)

# %%
for i,j, k in zip(a,b, c):
    print(i,j,k)
# Out:
#  1 2

# %%
for j, k in zip(b, c):
    print(j,k)
# Out:
# 1 2
# 2 4

# %%
url = 'https://app.powerbi.com/groups/6bfcff47-831c-42f4-9b91-698f09603fb6/reports/b32fa71a-f310-4ab0-aa0b-e7866c9a1477/17955ee8fb552ecc0d48?experience=power-bi'

# %%
from playwright.sync_api import sync_playwright

# 假设这段代码被一个异步函数调用，就会触发错误
def run_sync_playwright():
    with sync_playwright() as p:
        browser = p.chromium.launch(headless=True)
        page = browser.new_page()
        page.goto(url)
        print(page.title())
        browser.close()

# %%
run_sync_playwright()
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 run_sync_playwright()
#
# Cell In[5], line 5, in run_sync_playwright()
#       4 def run_sync_playwright():
# ----> 5     with sync_playwright() as p:
#       6         browser = p.chromium.launch(headless=True)
#       7         page = browser.new_page()
#
# File c:\Users\0185972\myenv\com\Lib\site-packages\playwright\sync_api\_context_manager.py:47, in PlaywrightContextManager.__enter__(self)
#      45             self._own_loop = True
#      46         if self._loop.is_running():
# ---> 47             raise Error(
#      48                 """It looks like you are using Playwright Sync API inside the asyncio loop.
#      49 Please use the Async API instead."""
#      50             )
#      52         # Create a new fiber for the protocol dispatcher. It will be pumping events
# ...

# %%
import asyncio
from playwright.async_api import async_playwright

async def main():
    # 使用 async with 和 async_playwright
    async with async_playwright() as p:
        # 每个I/O操作前都要加 await
        browser = await p.chromium.launch(headless=True)
        page = await browser.new_page()
        await page.goto("https://www.google.com")
        
        # 获取页面标题也需要 await
        page_title = await page.title()
        print(page_title)
        
        await browser.close()

# 使用 asyncio.run() 来执行你的异步主函数
if __name__ == "__main__":
    asyncio.run(main())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 20
#      18 # 使用 asyncio.run() 来执行你的异步主函数
#      19 if __name__ == "__main__":
# ---> 20     asyncio.run(main())
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\asyncio\runners.py:191, in run(main, debug, loop_factory)
#     161 """Execute the coroutine and return the result.
#     162
#     163 This function runs the passed coroutine, taking care of
#    (...)    187     asyncio.run(main())
#     188 """
#     189 if events._get_running_loop() is not None:
#     190     # fail fast with short traceback
# --> 191     raise RuntimeError(
#     192         "asyncio.run() cannot be called from a running event loop")
#     194 with Runner(debug=debug, loop_factory=loop_factory) as runner:
#     195     return runner.run(main)
#
# RuntimeError: asyncio.run() cannot be called from a running event loop
